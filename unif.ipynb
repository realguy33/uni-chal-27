# %%
import numpy as np
import pandas as pd
import streamlit as st
import altair as alt
from datetime import datetime
from subgrounds.subgraph import SyntheticField
import plotly.express as px

# %%
from subgrounds.subgrounds import Subgrounds

sg = Subgrounds()
uniarb = sg.load_subgraph('https://api.thegraph.com/subgraphs/name/ianlapham/arbitrum-minimal')
uniop =  sg.load_subgraph('https://api.thegraph.com/subgraphs/name/ianlapham/optimism-post-regenesis')
unipol = sg.load_subgraph('https://api.thegraph.com/subgraphs/name/ianlapham/uniswap-v3-polygon')

crvop = sg.load_subgraph('https://api.thegraph.com/subgraphs/name/convex-community/volume-optimism')
crvarb = sg.load_subgraph('https://api.thegraph.com/subgraphs/name/convex-community/volume-arbitrum')
crvpol = sg.load_subgraph('https://api.thegraph.com/subgraphs/name/convex-community/volume-matic')

# %% [markdown]
# #uniswap-arbitrum volume

# %%
voluniarb = uniarb.Query.uniswapDayDatas(
    first = 1000,
    orderby = uniarb.UniswapDayData.date,
    orderDirection = 'desc'
)


uniarb.UniswapDayData.datetime = SyntheticField(
    lambda date: str(datetime.fromtimestamp(date).strftime('%Y-%m-%d')),
    SyntheticField.STRING,
    uniarb.UniswapDayData.date
)

# %%
duniarb = sg.query_df([voluniarb.volumeUSD,voluniarb.datetime])
# Out:
# 2022-05-06 20:25:32.395 INFO    subgrounds: client.query: url = https://api.thegraph.com/subgraphs/name/ianlapham/arbitrum-minimal, variables = {'first0': 900, 'skip0': 0, 'lastOrderingValue0': None}
# query($first0: Int, $skip0: Int, $lastOrderingValue0: ID) {
#   x15a208f91084d254: uniswapDayDatas(first: $first0, skip: $skip0, orderBy: id, orderDirection: desc, where: {}) {
#     volumeUSD
#     date
#     id
#   }
# }

# %%
#duniarb

# %%
figuniarb = px.bar(duniarb, x= "uniswapDayDatas_datetime",y = "uniswapDayDatas_volumeUSD")

# %% [markdown]
# uniswap-optimism

# %%
voluniop = uniop.Query.uniswapDayDatas(
    first = 1000,
    orderby = uniop.UniswapDayData.date,
    orderDirection = 'desc'
)


uniop.UniswapDayData.datetime = SyntheticField(
    lambda date: str(datetime.fromtimestamp(date).strftime('%Y-%m-%d')),
    SyntheticField.STRING,
    uniop.UniswapDayData.date
)

duniop = sg.query_df([voluniop.volumeUSD,voluniop.datetime])

figuniop = px.bar(duniop, x= "uniswapDayDatas_datetime",y = "uniswapDayDatas_volumeUSD")
# Out:
# 2022-05-06 20:25:43.186 INFO    subgrounds: client.query: url = https://api.thegraph.com/subgraphs/name/ianlapham/optimism-post-regenesis, variables = {'first0': 900, 'skip0': 0, 'lastOrderingValue0': None}
# query($first0: Int, $skip0: Int, $lastOrderingValue0: ID) {
#   x5a28bf0a32fb5131: uniswapDayDatas(first: $first0, skip: $skip0, orderBy: id, orderDirection: desc, where: {}) {
#     volumeUSD
#     date
#     id
#   }
# }

# %% [markdown]
# #uniswap-polygon

# %%
volunipol = unipol.Query.uniswapDayDatas(
    first = 1000,
    orderby = unipol.UniswapDayData.date,
    orderDirection = 'desc'
)


unipol.UniswapDayData.datetime = SyntheticField(
    lambda date: str(datetime.fromtimestamp(date).strftime('%Y-%m-%d')),
    SyntheticField.STRING,
    unipol.UniswapDayData.date
)

dunipol = sg.query_df([volunipol.volumeUSD,volunipol.datetime])

figunipol = px.bar(duniop, x= "uniswapDayDatas_datetime",y = "uniswapDayDatas_volumeUSD")
# Out:
# 2022-05-06 20:25:50.560 INFO    subgrounds: client.query: url = https://api.thegraph.com/subgraphs/name/ianlapham/uniswap-v3-polygon, variables = {'first0': 900, 'skip0': 0, 'lastOrderingValue0': None}
# query($first0: Int, $skip0: Int, $lastOrderingValue0: ID) {
#   xdd3dc7ff0fbe538d: uniswapDayDatas(first: $first0, skip: $skip0, orderBy: id, orderDirection: desc, where: {}) {
#     volumeUSD
#     date
#     id
#   }
# }

# %% [markdown]
# #curve-arb

# %%
volcrvarb = crvarb.Query.dailySwapVolumeSnapshots(
    first = 2000,
    orderBy = crvarb.DailySwapVolumeSnapshot.timestamp,
    orderDirection = 'desc'
)

crvarb.DailySwapVolumeSnapshot.datetime = SyntheticField(
    lambda date: str(datetime.fromtimestamp(date).strftime('%Y-%m-%d')),
    SyntheticField.STRING,
    crvarb.DailySwapVolumeSnapshot.timestamp
)

dcrvarb = sg.query_df([volcrvarb.volumeUSD,volcrvarb.datetime,volcrvarb.pool.name])
# Out:
# 2022-05-06 20:25:53.659 INFO    subgrounds: client.query: url = https://api.thegraph.com/subgraphs/name/convex-community/volume-arbitrum, variables = {'first0': 900, 'skip0': 0, 'lastOrderingValue0': None}
# query($first0: Int, $skip0: Int, $lastOrderingValue0: BigInt) {
#   x4af1bffe3828f75c: dailySwapVolumeSnapshots(first: $first0, skip: $skip0, orderBy: timestamp, orderDirection: desc, where: {}) {
#     volumeUSD
#     timestamp
#     pool {
#       name
#     }
#     id
#   }
# }
# 2022-05-06 20:25:57.343 INFO    subgrounds: client.query: url = https://api.thegraph.com/subgraphs/name/convex-community/volume-arbitrum, variables = {'first0': 900, 'skip0': 0, 'lastOrderingValue0': '1638748800'}
# query($first0: Int, $skip0: Int, $lastOrderingValue0: BigInt) {
#   x4af1bffe3828f75c: dailySwapVolumeSnapshots(first: $first0, skip: $skip0, orderBy: timestamp, orderDirection: desc, where: {timestamp_lt: $lastOrderingValue0}) {
#     volumeUSD
#     timestamp
#     pool {
#       name
#     }
#     id
#   }
# }

# %%
figcrvarb = px.bar(dcrvarb, x= "dailySwapVolumeSnapshots_datetime",y = "dailySwapVolumeSnapshots_volumeUSD") 

figcrvarb.update_layout(
    xaxis_title="date",
    yaxis_title="volume",
)
# Out:
# C:\Users\hp\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\plotly\io\_renderers.py:8: DeprecationWarning:
#
# The distutils package is deprecated and slated for removal in Python 3.12. Use setuptools or check PEP 632 for potential alternatives

# %% [markdown]
# curve-optimism

# %%
volcrvop = crvop.Query.dailySwapVolumeSnapshots(
    first = 2000,
    orderBy = crvop.DailySwapVolumeSnapshot.timestamp,
    orderDirection = 'desc'
)

crvop.DailySwapVolumeSnapshot.datetime = SyntheticField(
    lambda date: str(datetime.fromtimestamp(date).strftime('%Y-%m-%d')),
    SyntheticField.STRING,
    crvop.DailySwapVolumeSnapshot.timestamp
)

dcrvop = sg.query_df([volcrvop.volumeUSD,volcrvop.datetime])

figcrvop = px.bar(dcrvop, x= "dailySwapVolumeSnapshots_datetime",y = "dailySwapVolumeSnapshots_volumeUSD") 

figcrvop.update_layout(
    xaxis_title="date",
    yaxis_title="volume",
)
# Out:
# 2022-05-06 20:25:58.394 INFO    subgrounds: client.query: url = https://api.thegraph.com/subgraphs/name/convex-community/volume-optimism, variables = {'first0': 900, 'skip0': 0, 'lastOrderingValue0': None}
# query($first0: Int, $skip0: Int, $lastOrderingValue0: BigInt) {
#   x4af1bffe3828f75c: dailySwapVolumeSnapshots(first: $first0, skip: $skip0, orderBy: timestamp, orderDirection: desc, where: {}) {
#     volumeUSD
#     timestamp
#     id
#   }
# }

# %% [markdown]
# #curve-polygon

# %%
volcrvpol = crvpol.Query.dailySwapVolumeSnapshots(
    first = 20000,
    orderBy = crvpol.DailySwapVolumeSnapshot.timestamp,
    orderDirection = 'desc'
)

crvpol.DailySwapVolumeSnapshot.datetime = SyntheticField(
    lambda date: str(datetime.fromtimestamp(date).strftime('%Y-%m-%d')),
    SyntheticField.STRING,
    crvpol.DailySwapVolumeSnapshot.timestamp
)

dcrvpol = sg.query_df([volcrvpol.volumeUSD,volcrvpol.datetime])

figcrvop = px.bar(dcrvop, x= "dailySwapVolumeSnapshots_datetime",y = "dailySwapVolumeSnapshots_volumeUSD") 

figcrvop.update_layout(
    xaxis_title="date",
    yaxis_title="volume",
)
# Out:
# 2022-05-06 20:25:59.369 INFO    subgrounds: client.query: url = https://api.thegraph.com/subgraphs/name/convex-community/volume-matic, variables = {'first0': 900, 'skip0': 0, 'lastOrderingValue0': None}
# query($first0: Int, $skip0: Int, $lastOrderingValue0: BigInt) {
#   xc96a4d305b7ce6fc: dailySwapVolumeSnapshots(first: $first0, skip: $skip0, orderBy: timestamp, orderDirection: desc, where: {}) {
#     volumeUSD
#     timestamp
#     id
#   }
# }
# 2022-05-06 20:26:01.886 INFO    subgrounds: client.query: url = https://api.thegraph.com/subgraphs/name/convex-community/volume-matic, variables = {'first0': 900, 'skip0': 0, 'lastOrderingValue0': '1644796800'}
# query($first0: Int, $skip0: Int, $lastOrderingValue0: BigInt) {
#   xc96a4d305b7ce6fc: dailySwapVolumeSnapshots(first: $first0, skip: $skip0, orderBy: timestamp, orderDirection: desc, where: {timestamp_lt: $lastOrderingValue0}) {
#     volumeUSD
#     timestamp
#     id
#   }
# }

# %%
dcrvop.to_csv("csvs/dcrvop.csv")
duniarb.to_csv("csvs/duniarb.csv")
duniop.to_csv("csvs/duniop.csv")
dunipol.to_csv("csvsdunipol.csv")
dcrvarb.to_csv("csvs/dcrvarb.csv")
dcrvpol.to_csv("csvs/dcrvpol.csv")
